# %%
import os
import time
import glob
import cv2
import tqdm
import numpy as np
import pandas as pd
import tensorflow as tf 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
physical_devices = tf.config.experimental.list_physical_devices('GPU')

try:
    tf.config.experimental.set_memory_growth(physical_devices[0], True)
except:
    print('No GPU detected')

# %%
training_data_path = r'.\Pneumonia\train' 
testing_data_path = r'.\Pneumonia\test'
validation_data_path = r'.\Pneumonia\val'

# %%
def createDataframe(path):
    files_normal = glob.glob(os.path.join(path, 'NORMAL') + r'\*.*')
    files_pneunomia = glob.glob(os.path.join(path, 'PNEUMONIA') + r'\*.*')
    
    files_normal = files_normal
    files_pneunomia = files_pneunomia
    
    def transformImage(file_name: str):
        img = cv2.imread(file_name)
        img = cv2.resize(img, (120, 120))
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        if (img.shape[2] == 1):
            print('Anomaly detected!!!')
        return img

    images = []
    labels = []
    for file in tqdm.tqdm(files_normal):
        img = transformImage(file)
        images.append(img)
        labels.append(0)
    for file in tqdm.tqdm(files_pneunomia):
        img = transformImage(file)
        images.append(img)
        labels.append(1)

    dataframe = pd.DataFrame()
    dataframe['images'] = images
    dataframe['labels'] = labels
    dataframe = dataframe.sample(frac=1).reset_index(drop=True)
    return dataframe

dataframe_training = createDataframe(training_data_path)
dataframe_validation = createDataframe(validation_data_path)
# Out:
# 100%|██████████| 1000/1000 [00:41<00:00, 24.27it/s]
# 100%|██████████| 1000/1000 [00:19<00:00, 52.44it/s]
# 100%|██████████| 308/308 [00:10<00:00, 28.41it/s]
# 100%|██████████| 308/308 [00:03<00:00, 82.27it/s]

# %%
X_train, y_train = np.stack(dataframe_training['images'] / 255).astype('float32'), dataframe_training['labels']
X_test, y_test = np.stack(dataframe_validation['images'] / 255).astype('float32'), dataframe_validation['labels']

X_train = np.reshape(X_train, (X_train.shape[0], 120, 120, 3))
y_train = tf.keras.utils.to_categorical(y_train)

X_test = np.reshape(X_test, (X_test.shape[0], 120, 120, 3))
y_test = tf.keras.utils.to_categorical(y_test)

# %%
def buildModel():
    input_layer = tf.keras.layers.Input(shape=(120, 120, 3), name='input_layer_1')
    model = tf.keras.layers.Conv2D(filters=32, kernel_size=3, padding='same', activation='relu', name='conv_b1_1')(input_layer)
    model = tf.keras.layers.Conv2D(filters=32, kernel_size=3, padding='same', activation='relu', name='conv_b1_2')(model)
    model = tf.keras.layers.MaxPooling2D((2, 2), name='pool_1')(model)
    
    model = tf.keras.layers.Conv2D(filters=64, kernel_size=3, padding='same', activation='relu', name='conv_b2_1')(model)
    model = tf.keras.layers.Conv2D(filters=64, kernel_size=3, padding='same', activation='relu', name='conv_b2_2')(model)
    model = tf.keras.layers.MaxPooling2D((2, 2), name='pool_2')(model)
    
    model = tf.keras.layers.Conv2D(filters=128, kernel_size=3, padding='same', activation='relu', name='conv_b3_1')(model)
    model = tf.keras.layers.Conv2D(filters=128, kernel_size=3, padding='same', activation='relu', name='conv_b3_2')(model)
    model = tf.keras.layers.MaxPooling2D((2, 2), name='pool_3')(model)
    
    model = tf.keras.layers.Conv2D(filters=256, kernel_size=3, padding='same', activation='relu', name='conv_b4_1')(model)
    model = tf.keras.layers.BatchNormalization(name='bn_1')(model)
    model = tf.keras.layers.Conv2D(filters=256, kernel_size=3, padding='same', activation='relu', name='conv_b4_2')(model)
    model = tf.keras.layers.BatchNormalization(name='bn_2')(model)
    model = tf.keras.layers.Conv2D(filters=256, kernel_size=3, padding='same', activation='relu', name='conv_b4_3')(model)
    model = tf.keras.layers.MaxPooling2D((2, 2), name='pool_4')(model)
    
    model = tf.keras.layers.Conv2D(filters=512, kernel_size=3, padding='same', activation='relu', name='conv_b5_1')(model)
    model = tf.keras.layers.BatchNormalization(name='bn_3')(model)
    model = tf.keras.layers.Conv2D(filters=512, kernel_size=3, padding='same', activation='relu', name='conv_b5_2')(model)
    model = tf.keras.layers.BatchNormalization(name='bn_4')(model)
    model = tf.keras.layers.Conv2D(filters=512, kernel_size=3, padding='same', activation='relu', name='conv_b5_3')(model)
    model = tf.keras.layers.MaxPooling2D((2, 2), name='pool_5')(model)
    
    model = tf.keras.layers.Flatten()(model)
    model = tf.keras.layers.Dense(1024, activation='relu', name='fc_1')(model)
    model = tf.keras.layers.Dropout(0.4)(model)
    model = tf.keras.layers.Dense(512, activation='relu', name='fc_2')(model)
    model = tf.keras.layers.Dropout(0.4)(model)
    output_layer = tf.keras.layers.Dense(2, activation='softmax', name='fc_3')(model)
    
    model = tf.keras.models.Model(input_layer, output_layer)
    return model

# %%
model_conv = buildModel()
model_conv.summary()
# Out:
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_layer_1 (InputLayer)   [(None, 120, 120, 3)]     0
# _________________________________________________________________
# conv_b1_1 (Conv2D)           (None, 120, 120, 32)      896
# _________________________________________________________________
# conv_b1_2 (Conv2D)           (None, 120, 120, 32)      9248
# _________________________________________________________________
# pool_1 (MaxPooling2D)        (None, 60, 60, 32)        0
# _________________________________________________________________
# conv_b2_1 (Conv2D)           (None, 60, 60, 64)        18496
# _________________________________________________________________
# conv_b2_2 (Conv2D)           (None, 60, 60, 64)        36928
# _________________________________________________________________
# pool_2 (MaxPooling2D)        (None, 30, 30, 64)        0
# _________________________________________________________________
# conv_b3_1 (Conv2D)           (None, 30, 30, 128)       73856
# _________________________________________________________________
# conv_b3_2 (Conv2D)           (None, 30, 30, 128)       147584
# _________________________________________________________________
# pool_3 (MaxPooling2D)        (None, 15, 15, 128)       0
# _________________________________________________________________
# conv_b4_1 (Conv2D)           (None, 15, 15, 256)       295168
# _________________________________________________________________
# bn_1 (BatchNormalization)    (None, 15, 15, 256)       1024
# _________________________________________________________________
# conv_b4_2 (Conv2D)           (None, 15, 15, 256)       590080
# _________________________________________________________________
# bn_2 (BatchNormalization)    (None, 15, 15, 256)       1024
# _________________________________________________________________
# conv_b4_3 (Conv2D)           (None, 15, 15, 256)       590080
# _________________________________________________________________
# pool_4 (MaxPooling2D)        (None, 7, 7, 256)         0
# _________________________________________________________________
# conv_b5_1 (Conv2D)           (None, 7, 7, 512)         1180160
# _________________________________________________________________
# bn_3 (BatchNormalization)    (None, 7, 7, 512)         2048
# _________________________________________________________________
# conv_b5_2 (Conv2D)           (None, 7, 7, 512)         2359808
# _________________________________________________________________
# bn_4 (BatchNormalization)    (None, 7, 7, 512)         2048
# _________________________________________________________________
# conv_b5_3 (Conv2D)           (None, 7, 7, 512)         2359808
# _________________________________________________________________
# pool_5 (MaxPooling2D)        (None, 3, 3, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 4608)              0
# _________________________________________________________________
# fc_1 (Dense)                 (None, 1024)              4719616
# _________________________________________________________________
# dropout (Dropout)            (None, 1024)              0
# _________________________________________________________________
# fc_2 (Dense)                 (None, 512)               524800
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# fc_3 (Dense)                 (None, 2)                 1026
# =================================================================
# Total params: 12,913,698
# Trainable params: 12,910,626
# Non-trainable params: 3,072
# _________________________________________________________________

# %%
class TimeLogger(tf.keras.callbacks.Callback):
    def __init__(self, name:str):
        self.log_name = name
        self.start_time = None
        self.log_time = []
        self.log_epoch = []
        
    def on_epoch_begin(self, epoch, logs=None):
        self.start_time = time.time()
    
    def on_epoch_end(self, epoch, logs=None):
        self.log_epoch.append(epoch)
        self.log_time.append(time.time() - self.start_time)
        
    def on_train_end(self, logs=None):
        dataframe_log = pd.DataFrame()
        dataframe_log['epochs'] = np.array(self.log_epoch) 
        dataframe_log['duration'] = np.array(self.log_time)
        dataframe_log.to_csv('log_duration\\' + self.log_name + '.csv', index=False)
        
early_stopping = tf.keras.callbacks.EarlyStopping(monitor='loss', patience=5, restore_best_weights=True)
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=3, verbose=1, min_lr=1e-7)

# %%
model_conv.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.01), 
                       loss=tf.keras.losses.CategoricalCrossentropy(),
                           metrics=['accuracy'])

# %%
# %%time
duration_callback = TimeLogger('Conv_duration_log')
history = model_conv.fit(X_train, y_train,
                          epochs=50, batch_size=64,
                              validation_data=(X_test, y_test),
                                  callbacks=[early_stopping, reduce_lr, duration_callback], verbose=1)
pd.DataFrame.from_dict(history.history).to_csv(r'log_history\history_conv.csv', index=False)
tf.keras.models.save_model(model_conv, r'log_weights\model_conv.h5')
# Out:
# Epoch 1/50
#  2/32 [>.............................] - ETA: 12s - loss: 555.5681 - accuracy: 0.5625WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.2174s vs `on_train_batch_end` time: 0.5448s). Check your callbacks.
# 32/32 [==============================] - 26s 819ms/step - loss: 56.7921 - accuracy: 0.5140 - val_loss: 279.4015 - val_accuracy: 0.5000
# Epoch 2/50
# 32/32 [==============================] - 14s 433ms/step - loss: 0.6919 - accuracy: 0.5420 - val_loss: 0.6955 - val_accuracy: 0.5114
# Epoch 3/50
# 32/32 [==============================] - 25s 795ms/step - loss: 0.6840 - accuracy: 0.5405 - val_loss: 1.2859 - val_accuracy: 0.5000
# Epoch 4/50
# 32/32 [==============================] - 25s 795ms/step - loss: 0.6394 - accuracy: 0.6290 - val_loss: 6.7313 - val_accuracy: 0.5000
# Epoch 5/50
# 32/32 [==============================] - ETA: 0s - loss: 0.5978 - accuracy: 0.6935
# Epoch 00005: ReduceLROnPlateau reducing learning rate to 0.0019999999552965165.
# 32/32 [==============================] - 26s 800ms/step - loss: 0.5978 - accuracy: 0.6935 - val_loss: 10.6334 - val_accuracy: 0.5000
# Epoch 6/50
# 32/32 [==============================] - 26s 814ms/step - loss: 0.5073 - accuracy: 0.7855 - val_loss: 4.8245 - val_accuracy: 0.5000
# Epoch 7/50
# 32/32 [==============================] - 25s 782ms/step - loss: 0.4803 - accuracy: 0.8035 - val_loss: 2.6096 - val_accuracy: 0.5065
# Epoch 8/50
# 32/32 [==============================] - ETA: 0s - loss: 0.4711 - accuracy: 0.8035
# Epoch 00008: ReduceLROnPlateau reducing learning rate to 0.0003999999724328518.
# 32/32 [==============================] - 25s 790ms/step - loss: 0.4711 - accuracy: 0.8035 - val_loss: 1.1684 - val_accuracy: 0.5698
# Epoch 9/50
# 32/32 [==============================] - 26s 803ms/step - loss: 0.4378 - accuracy: 0.8300 - val_loss: 0.7088 - val_accuracy: 0.6688
# Epoch 10/50
# 32/32 [==============================] - 20s 627ms/step - loss: 0.4283 - accuracy: 0.8360 - val_loss: 0.5455 - val_accuracy: 0.7419
# Epoch 11/50
# 32/32 [==============================] - 8s 254ms/step - loss: 0.4207 - accuracy: 0.8465 - val_loss: 0.3868 - val_accuracy: 0.8523
# Epoch 12/50
# 32/32 [==============================] - 24s 759ms/step - loss: 0.4176 - accuracy: 0.8440 - val_loss: 0.3457 - val_accuracy: 0.8653
# Epoch 13/50
# 32/32 [==============================] - 26s 800ms/step - loss: 0.4039 - accuracy: 0.8520 - val_loss: 0.3326 - val_accuracy: 0.8604
# Epoch 14/50
# 32/32 [==============================] - 26s 810ms/step - loss: 0.4031 - accuracy: 0.8520 - val_loss: 0.3259 - val_accuracy: 0.8685
# Epoch 15/50
# 32/32 [==============================] - 26s 799ms/step - loss: 0.3815 - accuracy: 0.8455 - val_loss: 0.3149 - val_accuracy: 0.8782
# Epoch 16/50
# 32/32 [==============================] - 26s 824ms/step - loss: 0.3966 - accuracy: 0.8530 - val_loss: 0.3136 - val_accuracy: 0.8799
# Epoch 17/50
# 32/32 [==============================] - 26s 816ms/step - loss: 0.3751 - accuracy: 0.8610 - val_loss: 0.3098 - val_accuracy: 0.8718
# Epoch 18/50
# 32/32 [==============================] - 20s 623ms/step - loss: 0.3567 - accuracy: 0.8670 - val_loss: 0.2942 - val_accuracy: 0.8782
# Epoch 19/50
# 32/32 [==============================] - 8s 262ms/step - loss: 0.3470 - accuracy: 0.8725 - val_loss: 0.2850 - val_accuracy: 0.8896
# Epoch 20/50
# 32/32 [==============================] - 26s 809ms/step - loss: 0.3420 - accuracy: 0.8705 - val_loss: 0.2742 - val_accuracy: 0.9010
# Epoch 21/50
# 32/32 [==============================] - 26s 800ms/step - loss: 0.3206 - accuracy: 0.8740 - val_loss: 0.2759 - val_accuracy: 0.8880
# Epoch 22/50
# 32/32 [==============================] - 26s 801ms/step - loss: 0.3316 - accuracy: 0.8795 - val_loss: 0.2683 - val_accuracy: 0.8961
# Epoch 23/50
# 32/32 [==============================] - 12s 387ms/step - loss: 0.3297 - accuracy: 0.8755 - val_loss: 0.2749 - val_accuracy: 0.8945
# Epoch 24/50
# 32/32 [==============================] - 25s 795ms/step - loss: 0.3333 - accuracy: 0.8770 - val_loss: 0.2535 - val_accuracy: 0.9091
# Epoch 25/50
# 32/32 [==============================] - 25s 793ms/step - loss: 0.3104 - accuracy: 0.8750 - val_loss: 0.2469 - val_accuracy: 0.9058
# Epoch 26/50
# 32/32 [==============================] - 26s 803ms/step - loss: 0.2847 - accuracy: 0.8810 - val_loss: 0.2892 - val_accuracy: 0.8718
# Epoch 27/50
# 32/32 [==============================] - 14s 443ms/step - loss: 0.2905 - accuracy: 0.8840 - val_loss: 0.2460 - val_accuracy: 0.9042
# Epoch 28/50
# 32/32 [==============================] - 12s 374ms/step - loss: 0.2875 - accuracy: 0.8995 - val_loss: 0.2396 - val_accuracy: 0.8994
# Epoch 29/50
# 32/32 [==============================] - 25s 793ms/step - loss: 0.2631 - accuracy: 0.8960 - val_loss: 0.2131 - val_accuracy: 0.9107
# Epoch 30/50
# 32/32 [==============================] - 25s 791ms/step - loss: 0.2585 - accuracy: 0.8995 - val_loss: 0.2158 - val_accuracy: 0.9156
# Epoch 31/50
# 32/32 [==============================] - 25s 792ms/step - loss: 0.2721 - accuracy: 0.8985 - val_loss: 0.2290 - val_accuracy: 0.9172
# Epoch 32/50
# 32/32 [==============================] - ETA: 0s - loss: 0.2528 - accuracy: 0.8940
# Epoch 00032: ReduceLROnPlateau reducing learning rate to 7.999999215826393e-05.
# 32/32 [==============================] - 26s 818ms/step - loss: 0.2528 - accuracy: 0.8940 - val_loss: 0.2676 - val_accuracy: 0.8977
# Epoch 33/50
# 32/32 [==============================] - 25s 784ms/step - loss: 0.2629 - accuracy: 0.8940 - val_loss: 0.2045 - val_accuracy: 0.9205
# Epoch 34/50
# 32/32 [==============================] - 25s 792ms/step - loss: 0.2297 - accuracy: 0.9045 - val_loss: 0.2024 - val_accuracy: 0.9205
# Epoch 35/50
# 32/32 [==============================] - 16s 512ms/step - loss: 0.2355 - accuracy: 0.9110 - val_loss: 0.2003 - val_accuracy: 0.9205
# Epoch 36/50
# 32/32 [==============================] - 9s 271ms/step - loss: 0.2306 - accuracy: 0.9080 - val_loss: 0.2069 - val_accuracy: 0.9269
# Epoch 37/50
# 32/32 [==============================] - 17s 538ms/step - loss: 0.2325 - accuracy: 0.9130 - val_loss: 0.2104 - val_accuracy: 0.9253
# Epoch 38/50
# 32/32 [==============================] - ETA: 0s - loss: 0.2232 - accuracy: 0.9150
# Epoch 00038: ReduceLROnPlateau reducing learning rate to 1.599999814061448e-05.
# 32/32 [==============================] - 8s 260ms/step - loss: 0.2232 - accuracy: 0.9150 - val_loss: 0.2060 - val_accuracy: 0.9253
# Epoch 39/50
# 32/32 [==============================] - 20s 615ms/step - loss: 0.2136 - accuracy: 0.9135 - val_loss: 0.2082 - val_accuracy: 0.9253
# Epoch 40/50
# 32/32 [==============================] - 25s 785ms/step - loss: 0.2254 - accuracy: 0.9160 - val_loss: 0.2102 - val_accuracy: 0.9237
# Epoch 41/50
# 32/32 [==============================] - ETA: 0s - loss: 0.2203 - accuracy: 0.9110
# Epoch 00041: ReduceLROnPlateau reducing learning rate to 3.199999628122896e-06.
# 32/32 [==============================] - 25s 791ms/step - loss: 0.2203 - accuracy: 0.9110 - val_loss: 0.2142 - val_accuracy: 0.9302
# Epoch 42/50
# 32/32 [==============================] - 27s 830ms/step - loss: 0.2164 - accuracy: 0.9115 - val_loss: 0.2172 - val_accuracy: 0.9302
# Epoch 43/50
# 32/32 [==============================] - 12s 389ms/step - loss: 0.2334 - accuracy: 0.9105 - val_loss: 0.2187 - val_accuracy: 0.9302
# Epoch 44/50
# 32/32 [==============================] - ETA: 0s - loss: 0.2197 - accuracy: 0.9145
# Epoch 00044: ReduceLROnPlateau reducing learning rate to 6.399999165296323e-07.
# 32/32 [==============================] - 8s 260ms/step - loss: 0.2197 - accuracy: 0.9145 - val_loss: 0.2204 - val_accuracy: 0.9302
# Wall time: 16min 24s
